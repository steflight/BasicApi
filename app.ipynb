# %% [markdown]
# <a href="https://colab.research.google.com/github/steflight/BasicApi/blob/master/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vanna
import vanna
from vanna.remote import VannaDefault
vn = VannaDefault(model='chinook', api_key=vanna.get_api_key('agoumekoufanas@gmail.com'))
vn.connect_to_sqlite('https://vanna.ai/Chinook.sqlite')
vn.ask("What are the top 10 albums by sales?")
# Out:
# ...
# Check your email for the code and enter it here: CP8VVN
# ...

# %%
from vanna.flask import VannaFlaskApp
VannaFlaskApp(vn).run()

# %% [markdown]
# ## Here's what you'll get
# ![vanna-flask](https://vanna.ai/blog/img/vanna-flask.gif)
